# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/lichess_games_raw.csv')

# %%
df['white_elo'].hist(bins=50)
# Out:
# <Axes: >

# %%
df['black_elo'].hist(bins=50)
# Out:
# <Axes: >
